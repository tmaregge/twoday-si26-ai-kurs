# %% [markdown]
# # Utforskning
#
# Her kan du utvikle og teste funksjonalitet iterativt!

# %%
# Denne kodesnutten gjør at Jupyter Notebook automatisk 
# laster inn de siste endringene i koden uten at du trenger å restarte kernelen.
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
